# %%
#importing the required libraries:
import tensorflow as tf
import nltk
from nltk.corpus import stopwords 
from sklearn.naive_bayes import MultinomialNB  
from nltk.stem import WordNetLemmatizer
from sklearn.svm import SVC 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- ---------
# absl-py                           2.1.0
# aiobotocore                       2.7.0
# aiohttp                           3.9.3
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.12
# altair                            5.0.1
# anaconda-anon-usage               0.4.3
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.1.4
# anaconda-navigator                2.5.2
# anaconda-project                  0.11.1
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# astropy                           5.3.4
# ...

# %%
# !pip install cv2
import cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 get_ipython().system('pip install cv2')
# ----> 2 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
#Now datapreprocessing:
data = pd.read_csv('sentiment_analysis_dataset.csv')

# %%
text = data['C:/Users/ADMIN/Desktop/ML/Epoch/target_labels']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C:/Users/ADMIN/Desktop/ML/Epoch/target_labels'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ...

# %%
import cv2
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import pandas as pd


def load_alphabet_data(data_dir):

  X, y = [], []
  for filename in os.listdir(data_dir):
    # Extracting label from filename 
    label = filename.split("_")[0]
    # Load images and preprocess them (grayscaling, resize and normalize)
    image = cv2.imread(os.path.join(data_dir, filename))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (28, 28))  
    image = image / 255.0
    X.append(image.reshape(-1))  # Flattening the images for neural network input
    y.append(label)
  return np.array(X), np.array(y)


def load_sentiment_data(data_path):

  data = pd.read_csv(data_path)
  text = data["text"] 
  labels = data["sentiment"]

  nltk.download('stopwords')
  stop_words = stopwords.words("english")
  lemmatizer = WordNetLemmatizer()

  processed_text = []
  for sentence in text:
    # Tokenization
    words = nltk.word_tokenize(sentence.lower())
    # Filtering stop words
    filtered_words = [word for word in words if word not in stop_words]
    # Lemmatization (optional)
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
    # Join back into a string
    processed_text.append(" ".join(lemmatized_words))

  return processed_text, labels


data_dir = "Desktop/ML/Epoch/alphabets_28x28.csv"  # Replace with your data directory
X_train, y_train = load_alphabet_data(data_dir)

data_path = "Desktop/ML/Epoch/sentiment_analysis_dataset.csv"  # Replace with your data path
processed_text, sentiment_labels = load_sentiment_data(data_path)

print("Loaded alphabet data:", X_train.shape, y_train.shape)
print("Loaded sentiment data:", len(processed_text), len(sentiment_labels))
